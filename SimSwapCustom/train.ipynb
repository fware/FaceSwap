# %% [markdown]
# #Training Demo
# This is a simple example for training the SimSwap 224*224 with VGGFace2-224.
#
# Code path: https://github.com/neuralchen/SimSwap
# If you like the SimSwap project, please star it!
# Paper path: https://arxiv.org/pdf/2106.06340v1.pdf or https://dl.acm.org/doi/10.1145/3394171.3413630

# %%
# !nvidia-smi
# Out:
# Sun May 10 23:51:05 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX PRO 6000 Blac...    Off |   00000000:05:00.0 Off |                    0 |
# | N/A   30C    P0             47W /  600W |       0MiB /  97887MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# Installation
# All file changes made by this notebook are temporary. You can try to mount your own google drive to store files if you want.

# %% [markdown]
# #Get Scripts

# %%
# !git clone https://github.com/neuralchen/SimSwap
# !cd SimSwap && git pull
# Out:
# Cloning into 'SimSwap'...
# remote: Enumerating objects: 1141, done.
# remote: Counting objects: 100% (508/508), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 1141 (delta 419), reused 382 (delta 382), pack-reused 633 (from 1)
# Receiving objects: 100% (1141/1141), 211.46 MiB | 41.20 MiB/s, done.
# Resolving deltas: 100% (601/601), done.
# Already up to date.

# %% [markdown]
# # Install Blocks

# %%
# !pip install googledrivedownloader
# !pip install timm==0.5.4
# !wget -P SimSwap/arcface_model https://github.com/neuralchen/SimSwap/releases/download/1.0/arcface_checkpoint.tar
# Out:
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from googledrivedownloader) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->googledrivedownloader) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->googledrivedownloader) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->googledrivedownloader) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->googledrivedownloader) (2026.4.22)
# Collecting timm==0.5.4
#   Downloading timm-0.5.4-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.12/dist-packages (from timm==0.5.4) (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm==0.5.4) (0.25.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->timm==0.5.4) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.4->timm==0.5.4) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision->timm==0.5.4) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->timm==0.5.4) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.4->timm==0.5.4) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.4->timm==0.5.4) (3.0.3)
# Downloading timm-0.5.4-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 kB 21.2 MB/s eta 0:00:00
# Installing collected packages: timm
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.26
#     Uninstalling timm-1.0.26:
#       Successfully uninstalled timm-1.0.26
# Successfully installed timm-0.5.4
# --2026-05-10 23:51:37--  https://github.com/neuralchen/SimSwap/releases/download/1.0/arcface_checkpoint.tar
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/374891081/f01468b3-446b-4867-8c78-6d496183f9e6?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-05-11T00%3A36%3A20Z&rscd=attachment%3B+filename%3Darcface_checkpoint.tar&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-05-10T23%3A35%3A35Z&ske=2026-05-11T00%3A36%3A20Z&sks=b&skv=2018-11-09&sig=hWvEVmvK5VN7cCpH0wsOXgwYpqhO9rE%2BUdV4TDj%2BuLI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3ODQ2MDY5NywibmJmIjoxNzc4NDU3MDk3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.lWRcbcyJqZJnwrrj4OMykQUOdV6q9NQfQw1Ck5Otqkg&response-content-disposition=attachment%3B%20filename%3Darcface_checkpoint.tar&response-content-type=application%2Foctet-stream [following]
# --2026-05-10 23:51:37--  https://release-assets.githubusercontent.com/github-production-release-asset/374891081/f01468b3-446b-4867-8c78-6d496183f9e6?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-05-11T00%3A36%3A20Z&rscd=attachment%3B+filename%3Darcface_checkpoint.tar&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-05-10T23%3A35%3A35Z&ske=2026-05-11T00%3A36%3A20Z&sks=b&skv=2018-11-09&sig=hWvEVmvK5VN7cCpH0wsOXgwYpqhO9rE%2BUdV4TDj%2BuLI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3ODQ2MDY5NywibmJmIjoxNzc4NDU3MDk3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.lWRcbcyJqZJnwrrj4OMykQUOdV6q9NQfQw1Ck5Otqkg&response-content-disposition=attachment%3B%20filename%3Darcface_checkpoint.tar&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 209280521 (200M) [application/octet-stream]
# Saving to: ‘SimSwap/arcface_model/arcface_checkpoint.tar’
#
# arcface_checkpoint. 100%[===================>] 199.58M  35.6MB/s    in 6.7s
#
# 2026-05-10 23:51:44 (29.8 MB/s) - ‘SimSwap/arcface_model/arcface_checkpoint.tar’ saved [209280521/209280521]

# %% [markdown]
# #Download the Training Dataset
# We employ the cropped VGGFace2-224 dataset for this toy training demo.
#
# You can download the dataset from our google driver https://drive.google.com/file/d/19pWvdEHS-CEG6tW3PdxdtZ5QEymVjImc/view?usp=sharing
#
# ***Please check the dataset in dir /content/TrainingData***
#
# ***If dataset already exists in /content/TrainingData, please do not run blow scripts!***

# %%
# %mkdir /content/TrainingData
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=19pWvdEHS-CEG6tW3PdxdtZ5QEymVjImc' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=19pWvdEHS-CEG6tW3PdxdtZ5QEymVjImc" -O /content/TrainingData/vggface2_crop_arcfacealign_224.tar && rm -rf /tmp/cookies.txt
# %cd /content/
# !tar -xzvf /content/TrainingData/vggface2_crop_arcfacealign_224.tar -C /content/TrainingData
#  !rm /content/TrainingData/vggface2_crop_arcfacealign_224.tar

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/FaceSwapML
# Out:
# /content/drive/MyDrive/FaceSwapML

# %%
# !tar -xzf lfw_dataset.tar.gz -C /content/

# %%
# !ls /content/
# Out:
# drive  lfw_funneled  lfw_funneled_aligned  sample_data	SimSwap

# %%
# %mkdir /content/lfw_funneled_aligned

# %%
# %cd /content/SimSwap/insightface_func/models/
# Out:
# /content/SimSwap/insightface_func/models

# %%
# !ls
# Out:
# antelopev2.zip

# %%
# !unzip antelopev2.zip

# %%
# %cd antelopev2/
# Out:
# /content/SimSwap/insightface_func/models/antelopev2

# %%
# %cp /content/drive/MyDrive/FaceSwapML/1k3d68.onnx .

# %%
# !ls -al
# Out:
# total 417552
# drwx------ 2 root root      4096 May 12 01:10 .
# drwxr-xr-x 3 root root      4096 May 12 00:57 ..
# -rw------- 1 root root 143607619 May 12 01:10 1k3d68.onnx
# -rw------- 1 root root   5030888 Jan 28  2022 2d106det.onnx
# -rw------- 1 root root   1322532 Jan 28  2022 genderage.onnx
# -rw------- 1 root root 260665334 Jan 28  2022 glintr100.onnx
# -rw-r--r-- 1 root root  16923827 May 12 01:01 scrfd_10g_bnkps.onnx

# %%
# %cd /content/drive//MyDrive/FaceSwapML/SimSwapModels/
# Out:
# /content/drive/MyDrive/FaceSwapML/SimSwapModels

# %%
# !unzip checkpoints.zip
# Out:
# Archive:  checkpoints.zip
#    creating: people/
#   inflating: people/iter.txt
#   inflating: people/latest_net_D1.pth
#   inflating: people/latest_net_D2.pth
#   inflating: people/latest_net_G.pth
#   inflating: people/loss_log.txt
#   inflating: people/opt.txt
#    creating: people/web/
#    creating: people/web/images/

# %%
# !pip install insightface onnxruntime-gpu
# Out:
# Collecting insightface
#   Downloading insightface-0.7.3.tar.gz (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.5/439.5 kB 18.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting onnxruntime-gpu
#   Downloading onnxruntime_gpu-1.26.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from insightface) (2.0.2)
# Collecting onnx (from insightface)
#   Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from insightface) (4.67.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from insightface) (2.32.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from insightface) (3.10.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from insightface) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from insightface) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from insightface) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from insightface) (0.25.2)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from insightface) (1.13)
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (from insightface) (3.0.12)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (from insightface) (2.0.8)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.12/dist-packages (from insightface) (3.17.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (25.12.19)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (26.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (5.29.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from albumentations->insightface) (6.0.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations->insightface) (2.12.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations->insightface) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations->insightface) (4.13.0.92)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->insightface) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->insightface) (6.5.16)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (2.9.0.post0)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx->insightface) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx->insightface) (0.5.4)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable->insightface) (0.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->insightface) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->insightface) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->insightface) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->insightface) (2026.4.22)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->insightface) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->insightface) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->insightface) (2026.4.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->insightface) (0.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->insightface) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->insightface) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->insightface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->insightface) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->insightface) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->insightface) (1.17.0)
# Downloading onnxruntime_gpu-1.26.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (277.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.0/277.0 MB 9.4 MB/s eta 0:00:00
# Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 205.3 MB/s eta 0:00:00
# Building wheels for collected packages: insightface
#   Building wheel for insightface (pyproject.toml) ... done
#   Created wheel for insightface: filename=insightface-0.7.3-cp312-cp312-linux_x86_64.whl size=1071486 sha256=7c66daeb270e79af994edc43d0a8edbb25581547676654d71f2d0ce473c444c9
#   Stored in directory: /root/.cache/pip/wheels/73/3c/e2/6d4815e8a8b33a2006554d65ce0d1f973e768f4c7a222fa675
# Successfully built insightface
# Installing collected packages: onnxruntime-gpu, onnx, insightface
# Successfully installed insightface-0.7.3 onnx-1.21.0 onnxruntime-gpu-1.26.0

# %%
# %cd /content/SimSwap/insightface_func/
# !python detect_and_align_faces.py
# Out:
# /content/SimSwap/insightface_func
# Load InsightFace antelopev2 ONNX models
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /content/SimSwap/insightface_func/models/antelopev2/1k3d68.onnx landmark_3d_68
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /content/SimSwap/insightface_func/models/antelopev2/2d106det.onnx landmark_2d_106
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /content/SimSwap/insightface_func/models/antelopev2/genderage.onnx genderage
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /content/SimSwap/insightface_func/models/antelopev2/glintr100.onnx recognition
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /content/SimSwap/insightface_func/models/antelopev2/scrfd_10g_bnkps.onnx detection
# set det-size: (640, 640)
# Find all the original face images
# 9572 total face images.
# Cycle through and align all face images.
# Write out to new directory /content/lfw_funneled_aligned
# 100% 9572/9572 [00:51<00:00, 185.41it/s]
# Total images scanned: 9572
# Successfully aligned and saved: 9542
# Faces not detected in: 30 images

# %%
# !unzip /content/SimSwap/checkpoints/checkpoints.zip
# Out:
# Archive:  /content/SimSwap/checkpoints/checkpoints.zip
#    creating: people/
#   inflating: people/iter.txt
#   inflating: people/latest_net_D1.pth
#   inflating: people/latest_net_D2.pth
#   inflating: people/latest_net_G.pth
#   inflating: people/loss_log.txt
#   inflating: people/opt.txt
#    creating: people/web/
#    creating: people/web/images/

# %%
# !ls
# Out:
# people	simswap224_test

# %%
# !nvidia-smi
# Out:
# Tue May 12 01:19:33 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX PRO 6000 Blac...    Off |   00000000:05:00.0 Off |                    0 |
# | N/A   36C    P0             48W /  600W |       0MiB /  97887MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# %mv /content/drive/MyDrive/FaceSwapML/SimSwapModels/people /content/drive/MyDrive/FaceSwapML/SimSwapModels/simswap224_test/

# %% [markdown]
# #Training
# Batch size must larger than 1!

# %%
# %cd /content/SimSwap
# !ls
# !python train.py --name simswap224_test --gpu_ids 0 --dataset /content/TrainingData/vggface2_crop_arcfacealign_224 --Gdeep False

# %%
# %cd /content/SimSwap
# !ls
# !python train.py \
  --name people \
  --which_epoch 50000 \
  --continue_train True \
  --dataset /content/lfw_funneled_aligned \
  --checkpoints_dir /content/drive/MyDrive/FaceSwapML/SimSwapModels \
  --gpu_ids 0 \
  --Gdeep False \
  --total_step 100000 \
  --batchSize 128
# Out:
# /content/SimSwap
#  arcface_model	       README.md
#  cog.yaml	      'SimSwap colab.ipynb'
#  crop_224	       simswaplogo
#  data		       test_one_image.py
#  demo_file	       test_video_swapmulti.py
#  docs		       test_video_swap_multispecific.py
#  download-weights.sh   test_video_swapsingle.py
#  insightface_func      test_video_swapspecific.py
#  LICENSE	       test_wholeimage_swapmulti.py
#  models		       test_wholeimage_swap_multispecific.py
#  MultiSpecific.ipynb   test_wholeimage_swapsingle.py
#  options	       test_wholeimage_swapspecific.py
#  output		       train.ipynb
#  parsing_model	       train.py
#  pg_modules	       util
#  predict.py
# 2026-05-12 01:22:54.475249: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-12 01:22:54.507297: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ------------ Options -------------
# Arc_path: arcface_model/arcface_checkpoint.tar
# Gdeep: False
# batchSize: 128
# beta1: 0.0
# checkpoints_dir: /content/drive/MyDrive/FaceSwapML/SimSwapModels
# continue_train: True
# dataset: /content/lfw_funneled_aligned
# gpu_ids: 0
# isTrain: True
# lambda_feat: 10.0
# lambda_id: 30.0
# lambda_rec: 10.0
# load_pretrain: ./checkpoints/simswap224_test
# log_frep: 200
# lr: 0.0004
# model_freq: 10000
# name: people
# niter: 10000
# niter_decay: 10000
# phase: train
# sample_freq: 1000
# total_step: 100000
# use_tensorboard: False
# which_epoch: 50000
# -------------- End ----------------
# Resuming from epoch 50000 at iteration 100000
# GPU used :  0
# ./checkpoints/simswap224_test/50000_net_G.pth not exists yet!
# Traceback (most recent call last):
#   File "/content/SimSwap/train.py", line 139, in <module>
#     model.initialize(opt)
#   File "/content/SimSwap/models/projected_model.py", line 82, in initialize
#     self.load_network(self.netG, 'G', opt.which_epoch, pretrained_path)
#   File "/content/SimSwap/models/base_model.py", line 64, in load_network
#     raise('Generator must exist!')
# TypeError: exceptions must derive from BaseException

# %%
# %rm -r /content/drive/MyDrive/FaceSwapML/SimSwapModels/people

# %%
# %cd /content/drive/MyDrive/FaceSwapML/SimSwapModels/people/
# Out:
# /content/drive/MyDrive/FaceSwapML/SimSwapModels/people

# %%
# !ls
# Out:
# 10000_net_D.pth    25000_net_G.pth    40000_optim_D.pth  5000_optim_G.pth
# 10000_net_G.pth    25000_optim_D.pth  40000_optim_G.pth  iter.txt
# 10000_optim_D.pth  25000_optim_G.pth  45000_net_D.pth	 latest_net_D1.pth
# 10000_optim_G.pth  30000_net_D.pth    45000_net_G.pth	 latest_net_D2.pth
# 15000_net_D.pth    30000_net_G.pth    45000_optim_D.pth  latest_net_G.pth
# 15000_net_G.pth    30000_optim_D.pth  45000_optim_G.pth  loss_log.txt
# 15000_optim_D.pth  30000_optim_G.pth  50000_net_D.pth	 opt.txt
# 15000_optim_G.pth  35000_net_D.pth    50000_net_G.pth	 samples
# 20000_net_D.pth    35000_net_G.pth    50000_optim_D.pth  summary
# 20000_net_G.pth    35000_optim_D.pth  50000_optim_G.pth  web
# 20000_optim_D.pth  35000_optim_G.pth  5000_net_D.pth
# 20000_optim_G.pth  40000_net_D.pth    5000_net_G.pth
# 25000_net_D.pth    40000_net_G.pth    5000_optim_D.pth

# %%
# !unzip /content/SimSwap/checkpoints/checkpoints.zip
# Out:
# Archive:  /content/SimSwap/checkpoints/checkpoints.zip
#    creating: people/
#   inflating: people/iter.txt
#   inflating: people/latest_net_D1.pth
#   inflating: people/latest_net_D2.pth
#   inflating: people/latest_net_G.pth
#   inflating: people/loss_log.txt
#   inflating: people/opt.txt
#    creating: people/web/
#    creating: people/web/images/

# %%
# %cd /content/drive/MyDrive/FaceSwapML/SimSwapModels/checkpoints/simswap224_test/
# Out:
# /content/drive/MyDrive/FaceSwapML/SimSwapModels/checkpoints/simswap224_test

# %%
# !ls /content/drive/MyDrive/FaceSwapML/SimSwapModels/people
# Out:
# 10000_net_D.pth    25000_net_G.pth    40000_optim_D.pth  5000_optim_G.pth
# 10000_net_G.pth    25000_optim_D.pth  40000_optim_G.pth  iter.txt
# 10000_optim_D.pth  25000_optim_G.pth  45000_net_D.pth	 latest_net_D1.pth
# 10000_optim_G.pth  30000_net_D.pth    45000_net_G.pth	 latest_net_D2.pth
# 15000_net_D.pth    30000_net_G.pth    45000_optim_D.pth  latest_net_G.pth
# 15000_net_G.pth    30000_optim_D.pth  45000_optim_G.pth  loss_log.txt
# 15000_optim_D.pth  30000_optim_G.pth  50000_net_D.pth	 opt.txt
# 15000_optim_G.pth  35000_net_D.pth    50000_net_G.pth	 samples
# 20000_net_D.pth    35000_net_G.pth    50000_optim_D.pth  summary
# 20000_net_G.pth    35000_optim_D.pth  50000_optim_G.pth  web
# 20000_optim_D.pth  35000_optim_G.pth  5000_net_D.pth
# 20000_optim_G.pth  40000_net_D.pth    5000_net_G.pth
# 25000_net_D.pth    40000_net_G.pth    5000_optim_D.pth

# %%
# !ls -al /content/drive/MyDrive/FaceSwapML/SimSwapModels/people
# Out:
# total 8070876
# -rw------- 1 root root  55247363 May 11 03:49 10000_net_D.pth
# -rw------- 1 root root 220263053 May 11 03:49 10000_net_G.pth
# -rw------- 1 root root  82689139 May 11 03:49 10000_optim_D.pth
# -rw------- 1 root root 440501803 May 11 03:49 10000_optim_G.pth
# -rw------- 1 root root  55247363 May 11 04:53 15000_net_D.pth
# -rw------- 1 root root 220263053 May 11 04:53 15000_net_G.pth
# -rw------- 1 root root  82689139 May 11 04:53 15000_optim_D.pth
# -rw------- 1 root root 440501803 May 11 04:53 15000_optim_G.pth
# -rw------- 1 root root  55247363 May 11 05:57 20000_net_D.pth
# -rw------- 1 root root 220263053 May 11 05:57 20000_net_G.pth
# -rw------- 1 root root  82689139 May 11 05:57 20000_optim_D.pth
# -rw------- 1 root root 440501803 May 11 05:57 20000_optim_G.pth
# -rw------- 1 root root  55247363 May 11 07:01 25000_net_D.pth
# -rw------- 1 root root 220263053 May 11 07:01 25000_net_G.pth
# -rw------- 1 root root  82689139 May 11 07:01 25000_optim_D.pth
# -rw------- 1 root root 440501803 May 11 07:01 25000_optim_G.pth
# -rw------- 1 root root  55247363 May 11 16:37 30000_net_D.pth
# -rw------- 1 root root 220263053 May 11 16:37 30000_net_G.pth
# -rw------- 1 root root  82689139 May 11 16:38 30000_optim_D.pth
# -rw------- 1 root root 440501803 May 11 16:37 30000_optim_G.pth
# -rw------- 1 root root  55247363 May 11 18:52 35000_net_D.pth
# -rw------- 1 root root 220263053 May 11 18:52 35000_net_G.pth
# -rw------- 1 root root  82689139 May 11 18:52 35000_optim_D.pth
# -rw------- 1 root root 440501803 May 11 18:52 35000_optim_G.pth
# -rw------- 1 root root  55247363 May 11 21:26 40000_net_D.pth
# -rw------- 1 root root 220263053 May 11 21:26 40000_net_G.pth
# -rw------- 1 root root  82689139 May 11 21:26 40000_optim_D.pth
# -rw------- 1 root root 440501803 May 11 21:26 40000_optim_G.pth
# -rw------- 1 root root  55247363 May 11 22:51 45000_net_D.pth
# -rw------- 1 root root 220263053 May 11 22:51 45000_net_G.pth
# -rw------- 1 root root  82689139 May 11 22:51 45000_optim_D.pth
# -rw------- 1 root root 440501803 May 11 22:51 45000_optim_G.pth
# -rw------- 1 root root  55247363 May 12 00:17 50000_net_D.pth
# -rw------- 1 root root 220263053 May 12 00:17 50000_net_G.pth
# -rw------- 1 root root  82689139 May 12 00:17 50000_optim_D.pth
# -rw------- 1 root root 440501803 May 12 00:17 50000_optim_G.pth
# -rw------- 1 root root  55246951 May 11 02:45 5000_net_D.pth
# -rw------- 1 root root 220262924 May 11 02:45 5000_net_G.pth
# -rw------- 1 root root  82689001 May 11 02:45 5000_optim_D.pth
# -rw------- 1 root root 440501491 May 11 02:45 5000_optim_G.pth
# -rw------- 1 root root        13 May 12 00:17 iter.txt
# -rw------- 1 root root  27865618 Apr 22  2020 latest_net_D1.pth
# -rw------- 1 root root  27865618 Apr 22  2020 latest_net_D2.pth
# -rw------- 1 root root 220243703 Apr 22  2020 latest_net_G.pth
# -rw------- 1 root root   1556408 May 12 00:50 loss_log.txt
# -rw------- 1 root root      1312 Apr 25  2020 opt.txt
# drwx------ 2 root root      4096 May 11 01:10 samples
# drwx------ 2 root root      4096 May 11 01:10 summary
# drwx------ 2 root root      4096 Apr 23  2020 web

# %%
# %cd /content/SimSwap
# !ls
# !python train.py \
  --name people \
  --which_epoch 50000 \
  --continue_train True \
  --dataset /content/lfw_funneled_aligned \
  --checkpoints_dir /content/drive/MyDrive/FaceSwapML/SimSwapModels \
  --load_pretrain /content/drive/MyDrive/FaceSwapML/SimSwapModels/people \
  --gpu_ids 0 \
  --Gdeep False \
  --total_step 100000 \
  --batchSize 128
# Out:
# /content/SimSwap
#  arcface_model	       README.md
#  cog.yaml	      'SimSwap colab.ipynb'
#  crop_224	       simswaplogo
#  data		       test_one_image.py
#  demo_file	       test_video_swapmulti.py
#  docs		       test_video_swap_multispecific.py
#  download-weights.sh   test_video_swapsingle.py
#  insightface_func      test_video_swapspecific.py
#  LICENSE	       test_wholeimage_swapmulti.py
#  models		       test_wholeimage_swap_multispecific.py
#  MultiSpecific.ipynb   test_wholeimage_swapsingle.py
#  options	       test_wholeimage_swapspecific.py
#  output		       train.ipynb
#  parsing_model	       train.py
#  pg_modules	       util
#  predict.py
# 2026-05-12 01:28:55.932512: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-12 01:28:55.964420: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ------------ Options -------------
# Arc_path: arcface_model/arcface_checkpoint.tar
# Gdeep: False
# batchSize: 128
# beta1: 0.0
# checkpoints_dir: /content/drive/MyDrive/FaceSwapML/SimSwapModels
# continue_train: True
# dataset: /content/lfw_funneled_aligned
# gpu_ids: 0
# isTrain: True
# lambda_feat: 10.0
# lambda_id: 30.0
# lambda_rec: 10.0
# load_pretrain: /content/drive/MyDrive/FaceSwapML/SimSwapModels/people
# log_frep: 200
# lr: 0.0004
# model_freq: 10000
# name: people
# niter: 10000
# niter_decay: 10000
# phase: train
# sample_freq: 1000
# total_step: 100000
# use_tensorboard: False
# which_epoch: 50000
# -------------- End ----------------
# Resuming from epoch 50000 at iteration 100000
# GPU used :  0
# processing Swapping dataset images...
# Finished preprocessing the Swapping dataset, total dirs number: 3994...
# Start to train at 2026-05-12 01:29:30
# /content/SimSwap/util/logo_class.py:35: SyntaxWarning: invalid escape sequence '\_'
#   \__ \ / __// __ `// ___// __/    / /  / ___// __ `// // __ \ / // __ \ / __ `/
#
#    _____  __                __     ______              _         _
#   / ___/ / /_ ____ _ _____ / /_   /_  __/_____ ____ _ (_)____   (_)____   ____ _
#   \__ \ / __// __ `// ___// __/    / /  / ___// __ `// // __ \ / // __ \ / __ `/
#  ___/ // /_ / /_/ // /   / /_     / /  / /   / /_/ // // / / // // / / // /_/ /
# /____/ \__/ \__,_//_/    \__/    /_/  /_/    \__,_//_//_/ /_//_//_/ /_/ \__, /
#                                                                        /____/
#
# ( step: 50199, ) G_Loss: 0.282 G_ID: 0.089 G_Rec: 0.638 G_feat_match: 1.100 D_fake: 0.730 D_real: 1.069 D_loss: 1.799
# ( step: 50399, ) G_Loss: 0.354 G_ID: 0.093 G_Rec: 0.494 G_feat_match: 1.075 D_fake: 0.792 D_real: 0.991 D_loss: 1.784
# ( step: 50599, ) G_Loss: 0.745 G_ID: 0.091 G_Rec: 0.677 G_feat_match: 1.107 D_fake: 0.514 D_real: 1.076 D_loss: 1.589
# ( step: 50799, ) G_Loss: 0.756 G_ID: 0.149 G_Rec: 1.212 G_feat_match: 1.101 D_fake: 0.574 D_real: 0.920 D_loss: 1.494
# ( step: 50999, ) G_Loss: 1.141 G_ID: 0.091 G_Rec: 0.678 G_feat_match: 1.091 D_fake: 0.380 D_real: 0.991 D_loss: 1.371
# Save test data
# ( step: 51199, ) G_Loss: 1.239 G_ID: 0.098 G_Rec: 0.592 G_feat_match: 1.037 D_fake: 0.320 D_real: 0.914 D_loss: 1.234
# ( step: 51399, ) G_Loss: 1.195 G_ID: 0.089 G_Rec: 0.625 G_feat_match: 1.069 D_fake: 0.369 D_real: 0.853 D_loss: 1.222
# ( step: 51599, ) G_Loss: 1.260 G_ID: 0.095 G_Rec: 0.592 G_feat_match: 1.048 D_fake: 0.316 D_real: 0.784 D_loss: 1.100
# ( step: 51799, ) G_Loss: 1.375 G_ID: 0.090 G_Rec: 0.573 G_feat_match: 1.056 D_fake: 0.386 D_real: 0.652 D_loss: 1.038
# ( step: 51999, ) G_Loss: 1.439 G_ID: 0.095 G_Rec: 0.952 G_feat_match: 1.077 D_fake: 0.325 D_real: 0.734 D_loss: 1.059
# Save test data
# ( step: 52199, ) G_Loss: 1.530 G_ID: 0.098 G_Rec: 0.448 G_feat_match: 1.051 D_fake: 0.217 D_real: 0.882 D_loss: 1.099
# ( step: 52399, ) G_Loss: 1.658 G_ID: 0.090 G_Rec: 0.822 G_feat_match: 1.055 D_fake: 0.290 D_real: 0.745 D_loss: 1.036
# ( step: 52599, ) G_Loss: 1.495 G_ID: 0.092 G_Rec: 0.717 G_feat_match: 1.042 D_fake: 0.340 D_real: 0.603 D_loss: 0.943
# ( step: 52799, ) G_Loss: 1.453 G_ID: 0.088 G_Rec: 0.595 G_feat_match: 1.033 D_fake: 0.224 D_real: 0.739 D_loss: 0.963
# ( step: 67599, ) G_Loss: 1.771 G_ID: 0.085 G_Rec: 0.614 G_feat_match: 0.917 D_fake: 0.144 D_real: 0.420 D_loss: 0.564
# ( step: 67799, ) G_Loss: 1.599 G_ID: 0.081 G_Rec: 0.599 G_feat_match: 0.916 D_fake: 0.150 D_real: 0.362 D_loss: 0.512
# ( step: 67999, ) G_Loss: 1.746 G_ID: 0.085 G_Rec: 0.516 G_feat_match: 0.911 D_fake: 0.163 D_real: 0.435 D_loss: 0.599
# Save test data
# ( step: 68199, ) G_Loss: 1.913 G_ID: 0.081 G_Rec: 0.592 G_feat_match: 0.914 D_fake: 0.174 D_real: 0.388 D_loss: 0.562
# ( step: 68399, ) G_Loss: 1.912 G_ID: 0.085 G_Rec: 0.651 G_feat_match: 0.901 D_fake: 0.203 D_real: 0.382 D_loss: 0.585
# ( step: 68599, ) G_Loss: 1.788 G_ID: 0.086 G_Rec: 0.697 G_feat_match: 0.892 D_fake: 0.181 D_real: 0.417 D_loss: 0.599
# ( step: 68799, ) G_Loss: 1.800 G_ID: 0.086 G_Rec: 0.504 G_feat_match: 0.909 D_fake: 0.156 D_real: 0.412 D_loss: 0.568
# ( step: 68999, ) G_Loss: 1.650 G_ID: 0.086 G_Rec: 0.904 G_feat_match: 0.901 D_fake: 0.213 D_real: 0.344 D_loss: 0.557
# Save test data
# ( step: 69199, ) G_Loss: 1.951 G_ID: 0.087 G_Rec: 0.682 G_feat_match: 0.922 D_fake: 0.149 D_real: 0.484 D_loss: 0.633
# ( step: 69399, ) G_Loss: 2.084 G_ID: 0.087 G_Rec: 0.515 G_feat_match: 0.923 D_fake: 0.187 D_real: 0.579 D_loss: 0.767
# ( step: 69599, ) G_Loss: 1.464 G_ID: 0.090 G_Rec: 0.548 G_feat_match: 0.921 D_fake: 0.225 D_real: 0.299 D_loss: 0.524
# ( step: 69799, ) G_Loss: 1.815 G_ID: 0.083 G_Rec: 0.554 G_feat_match: 0.902 D_fake: 0.177 D_real: 0.393 D_loss: 0.570
# ( step: 69999, ) G_Loss: 1.878 G_ID: 0.090 G_Rec: 0.560 G_feat_match: 0.905 D_fake: 0.186 D_real: 0.437 D_loss: 0.624
# Save test data
# saving the latest model (steps 70000)
# ( step: 70199, ) G_Loss: 1.839 G_ID: 0.088 G_Rec: 0.867 G_feat_match: 0.900 D_fake: 0.174 D_real: 0.537 D_loss: 0.710
# ( step: 70399, ) G_Loss: 1.966 G_ID: 0.087 G_Rec: 0.565 G_feat_match: 0.909 D_fake: 0.191 D_real: 0.355 D_loss: 0.546
# ( step: 70599, ) G_Loss: 1.599 G_ID: 0.086 G_Rec: 0.654 G_feat_match: 0.905 D_fake: 0.190 D_real: 0.353 D_loss: 0.543
# ( step: 70799, ) G_Loss: 1.823 G_ID: 0.088 G_Rec: 0.552 G_feat_match: 0.894 D_fake: 0.163 D_real: 0.458 D_loss: 0.621
# ( step: 70999, ) G_Loss: 1.717 G_ID: 0.087 G_Rec: 0.728 G_feat_match: 0.905 D_fake: 0.172 D_real: 0.310 D_loss: 0.482
# Save test data
# ( step: 78599, ) G_Loss: 1.598 G_ID: 0.088 G_Rec: 0.984 G_feat_match: 0.879 D_fake: 0.179 D_real: 0.404 D_loss: 0.583
# ( step: 78799, ) G_Loss: 1.622 G_ID: 0.087 G_Rec: 0.579 G_feat_match: 0.872 D_fake: 0.162 D_real: 0.443 D_loss: 0.605
# ( step: 78999, ) G_Loss: 1.625 G_ID: 0.086 G_Rec: 0.632 G_feat_match: 0.871 D_fake: 0.186 D_real: 0.325 D_loss: 0.512
# Save test data
# ( step: 79199, ) G_Loss: 1.723 G_ID: 0.087 G_Rec: 0.574 G_feat_match: 0.835 D_fake: 0.133 D_real: 0.509 D_loss: 0.642
# ( step: 79399, ) G_Loss: 1.670 G_ID: 0.085 G_Rec: 0.642 G_feat_match: 0.870 D_fake: 0.191 D_real: 0.297 D_loss: 0.488
# ( step: 79599, ) G_Loss: 1.599 G_ID: 0.088 G_Rec: 0.547 G_feat_match: 0.870 D_fake: 0.221 D_real: 0.347 D_loss: 0.568
# ( step: 79799, ) G_Loss: 1.954 G_ID: 0.088 G_Rec: 0.824 G_feat_match: 0.833 D_fake: 0.147 D_real: 0.490 D_loss: 0.637
# ( step: 79999, ) G_Loss: 1.575 G_ID: 0.082 G_Rec: 0.779 G_feat_match: 0.855 D_fake: 0.184 D_real: 0.387 D_loss: 0.572
# Save test data
# saving the latest model (steps 80000)
# ( step: 80199, ) G_Loss: 1.611 G_ID: 0.083 G_Rec: 0.794 G_feat_match: 0.831 D_fake: 0.174 D_real: 0.417 D_loss: 0.591
# ( step: 80399, ) G_Loss: 1.626 G_ID: 0.084 G_Rec: 0.623 G_feat_match: 0.855 D_fake: 0.202 D_real: 0.386 D_loss: 0.588
# ( step: 80599, ) G_Loss: 1.834 G_ID: 0.082 G_Rec: 0.591 G_feat_match: 0.838 D_fake: 0.175 D_real: 0.405 D_loss: 0.579
# ( step: 80799, ) G_Loss: 1.704 G_ID: 0.082 G_Rec: 0.746 G_feat_match: 0.876 D_fake: 0.169 D_real: 0.649 D_loss: 0.818
# ( step: 80999, ) G_Loss: 1.630 G_ID: 0.083 G_Rec: 0.560 G_feat_match: 0.844 D_fake: 0.180 D_real: 0.307 D_loss: 0.486
# Save test data
# ( step: 81199, ) G_Loss: 1.692 G_ID: 0.089 G_Rec: 0.655 G_feat_match: 0.867 D_fake: 0.167 D_real: 0.561 D_loss: 0.727
# ( step: 81399, ) G_Loss: 1.749 G_ID: 0.082 G_Rec: 0.822 G_feat_match: 0.855 D_fake: 0.147 D_real: 0.472 D_loss: 0.619
# ( step: 81599, ) G_Loss: 1.396 G_ID: 0.087 G_Rec: 0.967 G_feat_match: 0.870 D_fake: 0.221 D_real: 0.296 D_loss: 0.517
# ( step: 81799, ) G_Loss: 1.487 G_ID: 0.089 G_Rec: 0.700 G_feat_match: 0.819 D_fake: 0.201 D_real: 0.268 D_loss: 0.469
# ( step: 81999, ) G_Loss: 1.762 G_ID: 0.085 G_Rec: 0.516 G_feat_match: 0.846 D_fake: 0.143 D_real: 0.391 D_loss: 0.535
# Save test data
# ( step: 82199, ) G_Loss: 2.096 G_ID: 0.084 G_Rec: 0.590 G_feat_match: 0.836 D_fake: 0.221 D_real: 0.778 D_loss: 0.999
# ( step: 82399, ) G_Loss: 1.601 G_ID: 0.084 G_Rec: 0.512 G_feat_match: 0.833 D_fake: 0.176 D_real: 0.346 D_loss: 0.522
# ( step: 82599, ) G_Loss: 1.521 G_ID: 0.086 G_Rec: 0.669 G_feat_match: 0.822 D_fake: 0.165 D_real: 0.383 D_loss: 0.548
# ( step: 82799, ) G_Loss: 1.510 G_ID: 0.085 G_Rec: 0.563 G_feat_match: 0.850 D_fake: 0.167 D_real: 0.317 D_loss: 0.484
# ( step: 82999, ) G_Loss: 1.793 G_ID: 0.086 G_Rec: 0.510 G_feat_match: 0.847 D_fake: 0.160 D_real: 0.383 D_loss: 0.542
# Save test data
# ( step: 83199, ) G_Loss: 1.875 G_ID: 0.080 G_Rec: 0.500 G_feat_match: 0.840 D_fake: 0.141 D_real: 0.444 D_loss: 0.585
# ( step: 83399, ) G_Loss: 2.089 G_ID: 0.084 G_Rec: 0.942 G_feat_match: 0.839 D_fake: 0.177 D_real: 0.689 D_loss: 0.865
# ( step: 83599, ) G_Loss: 1.594 G_ID: 0.085 G_Rec: 0.612 G_feat_match: 0.838 D_fake: 0.178 D_real: 0.348 D_loss: 0.525
# ( step: 83799, ) G_Loss: 1.560 G_ID: 0.083 G_Rec: 0.498 G_feat_match: 0.840 D_fake: 0.185 D_real: 0.367 D_loss: 0.553
# ( step: 83999, ) G_Loss: 1.657 G_ID: 0.084 G_Rec: 0.622 G_feat_match: 0.846 D_fake: 0.176 D_real: 0.445 D_loss: 0.620
# Save test data
# ( step: 84199, ) G_Loss: 1.625 G_ID: 0.094 G_Rec: 0.543 G_feat_match: 0.847 D_fake: 0.180 D_real: 0.320 D_loss: 0.500
# ( step: 84399, ) G_Loss: 1.887 G_ID: 0.092 G_Rec: 0.718 G_feat_match: 0.864 D_fake: 0.153 D_real: 0.502 D_loss: 0.654
# ( step: 84599, ) G_Loss: 1.596 G_ID: 0.081 G_Rec: 0.712 G_feat_match: 0.834 D_fake: 0.191 D_real: 0.376 D_loss: 0.567
# ( step: 84799, ) G_Loss: 1.595 G_ID: 0.082 G_Rec: 0.551 G_feat_match: 0.815 D_fake: 0.209 D_real: 0.470 D_loss: 0.679
# ( step: 84999, ) G_Loss: 1.565 G_ID: 0.082 G_Rec: 0.583 G_feat_match: 0.808 D_fake: 0.183 D_real: 0.406 D_loss: 0.589
# Save test data
# ( step: 85199, ) G_Loss: 1.636 G_ID: 0.083 G_Rec: 0.657 G_feat_match: 0.837 D_fake: 0.127 D_real: 0.577 D_loss: 0.704
# ( step: 85399, ) G_Loss: 1.782 G_ID: 0.084 G_Rec: 0.602 G_feat_match: 0.848 D_fake: 0.181 D_real: 0.422 D_loss: 0.604
# ( step: 85599, ) G_Loss: 1.576 G_ID: 0.083 G_Rec: 0.649 G_feat_match: 0.833 D_fake: 0.149 D_real: 0.396 D_loss: 0.545
# ( step: 85799, ) G_Loss: 1.400 G_ID: 0.088 G_Rec: 0.747 G_feat_match: 0.830 D_fake: 0.194 D_real: 0.295 D_loss: 0.489
# ( step: 85999, ) G_Loss: 1.788 G_ID: 0.086 G_Rec: 0.906 G_feat_match: 0.837 D_fake: 0.168 D_real: 0.404 D_loss: 0.572
# Save test data
# ( step: 86199, ) G_Loss: 1.572 G_ID: 0.085 G_Rec: 0.594 G_feat_match: 0.816 D_fake: 0.207 D_real: 0.328 D_loss: 0.535
# ( step: 86399, ) G_Loss: 1.716 G_ID: 0.084 G_Rec: 0.558 G_feat_match: 0.822 D_fake: 0.143 D_real: 0.474 D_loss: 0.617
# ( step: 86599, ) G_Loss: 1.490 G_ID: 0.083 G_Rec: 0.684 G_feat_match: 0.807 D_fake: 0.169 D_real: 0.339 D_loss: 0.508
# ( step: 86799, ) G_Loss: 1.509 G_ID: 0.085 G_Rec: 0.504 G_feat_match: 0.813 D_fake: 0.151 D_real: 0.367 D_loss: 0.518
# ( step: 86999, ) G_Loss: 1.434 G_ID: 0.088 G_Rec: 0.594 G_feat_match: 0.807 D_fake: 0.232 D_real: 0.304 D_loss: 0.537
# Save test data
# ( step: 87199, ) G_Loss: 1.714 G_ID: 0.088 G_Rec: 0.630 G_feat_match: 0.820 D_fake: 0.203 D_real: 0.313 D_loss: 0.515
# ( step: 87399, ) G_Loss: 1.626 G_ID: 0.085 G_Rec: 0.529 G_feat_match: 0.816 D_fake: 0.169 D_real: 0.356 D_loss: 0.525
# ( step: 87599, ) G_Loss: 1.721 G_ID: 0.085 G_Rec: 0.564 G_feat_match: 0.829 D_fake: 0.168 D_real: 0.394 D_loss: 0.562
# ( step: 87799, ) G_Loss: 1.804 G_ID: 0.081 G_Rec: 0.645 G_feat_match: 0.838 D_fake: 0.188 D_real: 0.365 D_loss: 0.553
# ( step: 87999, ) G_Loss: 1.639 G_ID: 0.084 G_Rec: 0.557 G_feat_match: 0.822 D_fake: 0.187 D_real: 0.339 D_loss: 0.526
# Save test data
# ( step: 88199, ) G_Loss: 1.715 G_ID: 0.086 G_Rec: 0.595 G_feat_match: 0.825 D_fake: 0.157 D_real: 0.380 D_loss: 0.537
# ( step: 88399, ) G_Loss: 1.619 G_ID: 0.084 G_Rec: 0.523 G_feat_match: 0.824 D_fake: 0.178 D_real: 0.374 D_loss: 0.551
# ( step: 88599, ) G_Loss: 1.683 G_ID: 0.087 G_Rec: 0.724 G_feat_match: 0.834 D_fake: 0.155 D_real: 0.368 D_loss: 0.524
# ( step: 88799, ) G_Loss: 1.397 G_ID: 0.081 G_Rec: 0.605 G_feat_match: 0.814 D_fake: 0.202 D_real: 0.263 D_loss: 0.465
# ( step: 88999, ) G_Loss: 1.512 G_ID: 0.084 G_Rec: 0.959 G_feat_match: 0.804 D_fake: 0.253 D_real: 0.204 D_loss: 0.457
# Save test data
# ( step: 89199, ) G_Loss: 1.757 G_ID: 0.081 G_Rec: 0.559 G_feat_match: 0.823 D_fake: 0.142 D_real: 0.725 D_loss: 0.867
# ( step: 89399, ) G_Loss: 1.515 G_ID: 0.081 G_Rec: 0.559 G_feat_match: 0.801 D_fake: 0.194 D_real: 0.324 D_loss: 0.518
# ( step: 89599, ) G_Loss: 1.481 G_ID: 0.082 G_Rec: 0.614 G_feat_match: 0.786 D_fake: 0.136 D_real: 0.414 D_loss: 0.550
# ( step: 89799, ) G_Loss: 1.618 G_ID: 0.084 G_Rec: 0.564 G_feat_match: 0.814 D_fake: 0.172 D_real: 0.528 D_loss: 0.699
# ( step: 89999, ) G_Loss: 1.795 G_ID: 0.085 G_Rec: 0.586 G_feat_match: 0.814 D_fake: 0.156 D_real: 0.390 D_loss: 0.546
# Save test data
# saving the latest model (steps 90000)
# ( step: 90199, ) G_Loss: 1.543 G_ID: 0.083 G_Rec: 0.577 G_feat_match: 0.797 D_fake: 0.195 D_real: 0.348 D_loss: 0.543
# ( step: 90399, ) G_Loss: 1.490 G_ID: 0.086 G_Rec: 0.670 G_feat_match: 0.812 D_fake: 0.151 D_real: 0.347 D_loss: 0.499
# ( step: 90599, ) G_Loss: 1.572 G_ID: 0.082 G_Rec: 0.617 G_feat_match: 0.824 D_fake: 0.155 D_real: 0.353 D_loss: 0.508
# ( step: 90799, ) G_Loss: 1.723 G_ID: 0.086 G_Rec: 0.782 G_feat_match: 0.828 D_fake: 0.155 D_real: 0.360 D_loss: 0.515
# ( step: 90999, ) G_Loss: 1.658 G_ID: 0.082 G_Rec: 1.020 G_feat_match: 0.794 D_fake: 0.188 D_real: 0.384 D_loss: 0.571
# Save test data
# ( step: 91199, ) G_Loss: 1.578 G_ID: 0.078 G_Rec: 0.543 G_feat_match: 0.796 D_fake: 0.137 D_real: 0.558 D_loss: 0.696
# ( step: 91399, ) G_Loss: 1.849 G_ID: 0.084 G_Rec: 0.520 G_feat_match: 0.817 D_fake: 0.146 D_real: 0.434 D_loss: 0.580
# ( step: 91599, ) G_Loss: 1.643 G_ID: 0.084 G_Rec: 0.571 G_feat_match: 0.827 D_fake: 0.167 D_real: 0.304 D_loss: 0.471
# ( step: 91799, ) G_Loss: 1.546 G_ID: 0.086 G_Rec: 0.581 G_feat_match: 0.800 D_fake: 0.192 D_real: 0.313 D_loss: 0.505
# ( step: 91999, ) G_Loss: 1.485 G_ID: 0.090 G_Rec: 0.592 G_feat_match: 0.821 D_fake: 0.169 D_real: 0.364 D_loss: 0.532
# Save test data
# ( step: 92199, ) G_Loss: 1.608 G_ID: 0.087 G_Rec: 0.572 G_feat_match: 0.788 D_fake: 0.171 D_real: 0.364 D_loss: 0.535
# ( step: 92399, ) G_Loss: 1.650 G_ID: 0.086 G_Rec: 0.609 G_feat_match: 0.778 D_fake: 0.199 D_real: 0.340 D_loss: 0.539
# ( step: 92599, ) G_Loss: 1.614 G_ID: 0.083 G_Rec: 0.624 G_feat_match: 0.792 D_fake: 0.177 D_real: 0.307 D_loss: 0.484
# ( step: 92799, ) G_Loss: 1.249 G_ID: 0.083 G_Rec: 0.582 G_feat_match: 0.788 D_fake: 0.197 D_real: 0.269 D_loss: 0.467
# ( step: 92999, ) G_Loss: 1.687 G_ID: 0.083 G_Rec: 0.541 G_feat_match: 0.790 D_fake: 0.148 D_real: 0.618 D_loss: 0.766
# Save test data
# ( step: 93199, ) G_Loss: 1.393 G_ID: 0.083 G_Rec: 0.752 G_feat_match: 0.794 D_fake: 0.214 D_real: 0.354 D_loss: 0.568
# ( step: 93399, ) G_Loss: 1.574 G_ID: 0.081 G_Rec: 0.623 G_feat_match: 0.785 D_fake: 0.183 D_real: 0.530 D_loss: 0.712
# ( step: 93599, ) G_Loss: 1.640 G_ID: 0.082 G_Rec: 0.551 G_feat_match: 0.785 D_fake: 0.180 D_real: 0.399 D_loss: 0.579
# ( step: 93799, ) G_Loss: 1.626 G_ID: 0.080 G_Rec: 0.603 G_feat_match: 0.765 D_fake: 0.152 D_real: 0.479 D_loss: 0.631
# ( step: 93999, ) G_Loss: 1.399 G_ID: 0.081 G_Rec: 0.669 G_feat_match: 0.817 D_fake: 0.194 D_real: 0.303 D_loss: 0.497
# Save test data
# ( step: 94199, ) G_Loss: 1.636 G_ID: 0.082 G_Rec: 0.566 G_feat_match: 0.838 D_fake: 0.205 D_real: 0.322 D_loss: 0.527
# ( step: 94399, ) G_Loss: 1.559 G_ID: 0.081 G_Rec: 0.723 G_feat_match: 0.785 D_fake: 0.222 D_real: 0.375 D_loss: 0.598
# ( step: 94599, ) G_Loss: 1.515 G_ID: 0.087 G_Rec: 0.700 G_feat_match: 0.796 D_fake: 0.196 D_real: 0.349 D_loss: 0.544
# ( step: 94799, ) G_Loss: 1.395 G_ID: 0.083 G_Rec: 0.534 G_feat_match: 0.782 D_fake: 0.219 D_real: 0.262 D_loss: 0.481
# ( step: 94999, ) G_Loss: 1.583 G_ID: 0.080 G_Rec: 0.590 G_feat_match: 0.792 D_fake: 0.166 D_real: 0.360 D_loss: 0.527
# Save test data
# ( step: 95199, ) G_Loss: 1.695 G_ID: 0.093 G_Rec: 0.582 G_feat_match: 0.832 D_fake: 0.166 D_real: 0.374 D_loss: 0.539
# ( step: 95399, ) G_Loss: 1.510 G_ID: 0.086 G_Rec: 0.533 G_feat_match: 0.785 D_fake: 0.210 D_real: 0.241 D_loss: 0.451
# ( step: 95599, ) G_Loss: 1.498 G_ID: 0.084 G_Rec: 0.533 G_feat_match: 0.789 D_fake: 0.199 D_real: 0.351 D_loss: 0.550
# ( step: 95799, ) G_Loss: 1.492 G_ID: 0.083 G_Rec: 0.621 G_feat_match: 0.791 D_fake: 0.205 D_real: 0.293 D_loss: 0.498
# ( step: 95999, ) G_Loss: 1.442 G_ID: 0.083 G_Rec: 0.746 G_feat_match: 0.767 D_fake: 0.213 D_real: 0.338 D_loss: 0.551
# Save test data
# ( step: 96199, ) G_Loss: 1.759 G_ID: 0.088 G_Rec: 0.866 G_feat_match: 0.787 D_fake: 0.156 D_real: 0.397 D_loss: 0.553
# ( step: 96399, ) G_Loss: 1.557 G_ID: 0.080 G_Rec: 0.595 G_feat_match: 0.787 D_fake: 0.187 D_real: 0.409 D_loss: 0.597
# ( step: 96599, ) G_Loss: 1.543 G_ID: 0.076 G_Rec: 0.690 G_feat_match: 0.798 D_fake: 0.147 D_real: 0.400 D_loss: 0.547
# ( step: 96799, ) G_Loss: 1.516 G_ID: 0.119 G_Rec: 1.536 G_feat_match: 0.790 D_fake: 0.172 D_real: 0.274 D_loss: 0.445
# ( step: 96999, ) G_Loss: 1.597 G_ID: 0.080 G_Rec: 0.500 G_feat_match: 0.754 D_fake: 0.196 D_real: 0.279 D_loss: 0.476
# Save test data
# ( step: 97199, ) G_Loss: 1.587 G_ID: 0.086 G_Rec: 0.512 G_feat_match: 0.787 D_fake: 0.139 D_real: 0.395 D_loss: 0.534
# ( step: 97399, ) G_Loss: 1.541 G_ID: 0.086 G_Rec: 0.694 G_feat_match: 0.796 D_fake: 0.174 D_real: 0.295 D_loss: 0.469
# ( step: 97599, ) G_Loss: 1.435 G_ID: 0.082 G_Rec: 0.599 G_feat_match: 0.793 D_fake: 0.158 D_real: 0.345 D_loss: 0.504
# ( step: 97799, ) G_Loss: 1.529 G_ID: 0.082 G_Rec: 0.551 G_feat_match: 0.784 D_fake: 0.138 D_real: 0.440 D_loss: 0.578
# ( step: 97999, ) G_Loss: 1.549 G_ID: 0.079 G_Rec: 0.674 G_feat_match: 0.811 D_fake: 0.167 D_real: 0.323 D_loss: 0.491
# Save test data
# ( step: 98199, ) G_Loss: 1.379 G_ID: 0.080 G_Rec: 0.570 G_feat_match: 0.800 D_fake: 0.216 D_real: 0.254 D_loss: 0.470
# ( step: 98399, ) G_Loss: 1.667 G_ID: 0.082 G_Rec: 0.552 G_feat_match: 0.780 D_fake: 0.186 D_real: 0.331 D_loss: 0.517
# ( step: 98599, ) G_Loss: 1.710 G_ID: 0.081 G_Rec: 0.881 G_feat_match: 0.787 D_fake: 0.134 D_real: 0.467 D_loss: 0.601
# ( step: 98799, ) G_Loss: 1.396 G_ID: 0.081 G_Rec: 0.643 G_feat_match: 0.813 D_fake: 0.192 D_real: 0.291 D_loss: 0.483
# ( step: 98999, ) G_Loss: 1.484 G_ID: 0.082 G_Rec: 0.594 G_feat_match: 0.769 D_fake: 0.220 D_real: 0.312 D_loss: 0.531
# Save test data
# ( step: 99199, ) G_Loss: 1.611 G_ID: 0.083 G_Rec: 1.125 G_feat_match: 0.772 D_fake: 0.161 D_real: 0.372 D_loss: 0.533
# ( step: 99399, ) G_Loss: 1.692 G_ID: 0.082 G_Rec: 0.513 G_feat_match: 0.776 D_fake: 0.169 D_real: 0.345 D_loss: 0.513
# ( step: 99599, ) G_Loss: 1.622 G_ID: 0.085 G_Rec: 0.647 G_feat_match: 0.770 D_fake: 0.159 D_real: 0.591 D_loss: 0.750
# ( step: 99799, ) G_Loss: 1.672 G_ID: 0.080 G_Rec: 0.617 G_feat_match: 0.766 D_fake: 0.149 D_real: 0.444 D_loss: 0.593
# ( step: 99999, ) G_Loss: 1.491 G_ID: 0.082 G_Rec: 0.535 G_feat_match: 0.792 D_fake: 0.164 D_real: 0.381 D_loss: 0.545
# Save test data
# saving the latest model (steps 100000)
# Traceback (most recent call last):
#   File "/content/SimSwap/train.py", line 290, in <module>
#     wandb.finish()
#     ^^^^^
# NameError: name 'wandb' is not defined
